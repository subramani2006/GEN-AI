# %% [markdown]
# import cv2
# img = cv2.imread('Lenna_test_image.png')
# cv2.imshow("image", img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# **Resize the image**

# %%
import matplotlib.pyplot as plt
import cv2
image = cv2.imread('Lenna_test_image.png')


half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1050, 1610))

stretch_near = cv2.resize(image, (780, 540), 
               interpolation = cv2.INTER_LINEAR)
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4

for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])

plt.show()

# %%
from PIL import Image
img = Image.open('Lenna_test_image.png')
new_size = (800, 600)
resized_img = img.resize(new_size)
resized_img.save('Resized_Lenna_test_image.png')
resized_img.show()
width, height = img.size
scale_factor = 0.1
new_size = (int(width * scale_factor), int(height * scale_factor))
resized_img = img.resize(new_size)

# %% [markdown]
# **RGB to GRAY**

# %%
import cv2
img = cv2.imread('Lenna_test_image.png')
gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow('Grayscale Image', gray_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image
img = Image.open('Lenna_test_image.png')
gray_img = img.convert('L')
gray_img.show()
gray_img.save('Grayscale_Lenna_test_image.png')

# %% [markdown]
# **Histogram Equalisation**

# %%
import cv2
img = cv2.imread('Lenna_test_image.png', cv2.IMREAD_GRAYSCALE)
equalized_img = cv2.equalizeHist(img)
cv2.imshow('Original Image', img)
cv2.imshow('Equalized Image', equalized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
img = Image.open('Lenna_test_image.png').convert('L')  
img_array = np.array(img)
hist, bins = np.histogram(img_array.flatten(), bins=256, range=[0, 256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(255) / cdf[-1]
equalized_img_array = np.interp(img_array.flatten(), bins[:-1], cdf_normalized)
equalized_img_array = equalized_img_array.reshape(img_array.shape)
equalized_img = Image.fromarray(np.uint8(equalized_img_array))
img.show()
equalized_img.show()
equalized_img.save('Equalized_Lenna_test_image.png')

# %% [markdown]
# **OWN PICTURE**

# %%
import cv2
img = cv2.imread('Naruto .jpg')
cv2.imshow("image", img) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
img = cv2.imread('Naruto .jpg')
resized_img = cv2.resize(img, (800, 600))  
gray_img = cv2.cvtColor(resized_img, cv2.COLOR_BGR2GRAY)
equalized_img = cv2.equalizeHist(gray_img)
cv2.imshow("Original Image", img)
cv2.imshow("Resized Image", resized_img)
cv2.imshow("Grayscale Image", gray_img)
cv2.imshow("Equalized Image", equalized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt


img = Image.open('Naruto .jpg')
resized_img = img.resize((800, 600))
gray_img = resized_img.convert('L')
gray_img_array = np.array(gray_img)
hist, bins = np.histogram(gray_img_array.flatten(), bins=256, range=[0, 256])
cdf = hist.cumsum()
cdf_normalized = cdf * float(255) / cdf[-1]
equalized_img_array = np.interp(gray_img_array.flatten(), bins[:-1], cdf_normalized)
equalized_img_array = equalized_img_array.reshape(gray_img_array.shape)
equalized_img = Image.fromarray(np.uint8(equalized_img_array))
gray_img.show()
equalized_img.show()
resized_img.save('Resized_Naruto.jpg')
equalized_img.save('Equalized_Naruto.jpg')
